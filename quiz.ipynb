# %%
import pandas as pd
import numpy as np

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/00374/energydata_complete.csv"
df = pd.read_csv(url, error_bad_lines=False)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df
# Out:
#                       date  Appliances  lights         T1       RH_1  \
# 0      2016-01-11 17:00:00          60      30  19.890000  47.596667
# 1      2016-01-11 17:10:00          60      30  19.890000  46.693333
# 2      2016-01-11 17:20:00          50      30  19.890000  46.300000
# 3      2016-01-11 17:30:00          50      40  19.890000  46.066667
# 4      2016-01-11 17:40:00          60      40  19.890000  46.333333
# ...                    ...         ...     ...        ...        ...
# 19730  2016-05-27 17:20:00         100       0  25.566667  46.560000
# 19731  2016-05-27 17:30:00          90       0  25.500000  46.500000
# 19732  2016-05-27 17:40:00         270      10  25.500000  46.596667
# 19733  2016-05-27 17:50:00         420      10  25.500000  46.990000
# 19734  2016-05-27 18:00:00         430      10  25.500000  46.600000
#
#               T2       RH_2         T3       RH_3         T4  ...         T9  \
# ...

# %%
df_1 = df.drop(columns = ['date', 'lights'])
normalized_df = pd.DataFrame(scaler.fit_transform(df_1), columns = df_1.columns)
features_df = normalized_df.drop(columns = ['Appliances'])
target = normalized_df['Appliances']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
linear_model = LinearRegression() 
x_train, x_test, y_train, y_test = train_test_split(features_df, target, test_size = 0.3, random_state = 42)

linear_model.fit(x_train, y_train)
predicted_values = linear_model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_test, predicted_values)
round(mae, 2)
# Out:
# 0.05

# %%
rss = np.sum(np.square(y_test - predicted_values))
round(rss, 2)
# Out:
# 45.35

# %%
from sklearn.metrics import  mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, predicted_values))
round(rmse, 3)
# Out:
# 0.088

# %%
from sklearn.metrics import r2_score
r2Score = r2_score(y_test, predicted_value)
round(r2Score, 2)
# Out:
# 0.15

# %%
weights = pd.Series(linear_model.coef_, features_df.columns).sort_values()
weights_df = pd.DataFrame(weights)
weights_df.columns = ["Weights"]
weights_df
# Out:
#               Weights
# RH_2        -0.456698
# T_out       -0.321860
# T2          -0.236178
# T9          -0.189941
# RH_8        -0.157595
# RH_out      -0.077671
# RH_7        -0.044614
# RH_9        -0.039800
# T5          -0.015657
# T1          -0.003281
# rv1          0.000770
# rv2          0.000770
# Press_mm_hg  0.006839
# T7           0.010319
# Visibility   0.012307
# RH_5         0.016006
# RH_4         0.026386
# T4           0.028981
# Windspeed    0.029183
# RH_6         0.038049
# RH_3         0.096048
# T8           0.101995
# Tdewpoint    0.117758
# T6           0.236425
# T3           0.290627
# RH_1         0.553547

# %%
rmse = np.sqrt(mean_squared_error(y_test, predicted_values))
print(rmse)

from sklearn.linear_model import Ridge
ridge_reg = Ridge(alpha = 0.4)
ridge_reg.fit(x_train, y_train)
ridge_predicted = ridge_reg.predict(x_test)

from sklearn.metrics import  mean_squared_error
rmse_ridge = np.sqrt(mean_squared_error(y_test, ridge_predicted))
rmse_ridge
# Out:
# 0.08751444947661711
# 0.08753385704628003

# %%
from sklearn.linear_model import Lasso
lasso_reg = Lasso(alpha = 0.001)
lasso_reg.fit(x_train, y_train)

lasso_weights = pd.Series(lasso_reg.coef_, features_df.columns).sort_values()
lasso_weights_df = pd.DataFrame(lasso_weights)
lasso_weights_df.columns = ["Weights"]


lasso_weights_df[lasso_weights_df["Weights"] != 0]
# Out:
#             Weights
# RH_out    -0.049557
# RH_8      -0.000110
# Windspeed  0.002912
# RH_1       0.017880

# %%
lasso_predicted = lasso_reg.predict(x_test)

from sklearn.metrics import  mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, lasso_predicted))
round(rmse, 3)
# Out:
# 0.094
